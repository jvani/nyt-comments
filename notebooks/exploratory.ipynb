# %%
# %%capture
import sys
# !{sys.executable} -m pip install py2neo;
import py2neo
import pandas as pd

# %%
graph = py2neo.Graph('http://neo4j:7474')

# %% [markdown]
# # New York Times Comments
# The data contains information about the comments made on the articles published in New York Times in Jan-May 2017 and Jan-April 2018.
#
# See: https://www.kaggle.com/aashita/nyt-comments/home

# %% [markdown]
# ## Data Summary
# ### Nodes

# %%
def yield_record(cursor):
    halt = False
    while not halt:
        try:
            yield cur.next().data()
        except:
            halt = True
            
Ncomments = graph.run("""MATCH ()-[r:COMMENTED]->() RETURN count(*)""").next().data()['count(*)']
            
cur = graph.run("""MATCH (n)
RETURN
DISTINCT labels(n),
count(*) AS nNodes,
avg(size( (n)-[]-() ) ) as avgDeg,
stdev(size( (n)-[]-() ) ) as stdDeg,
percentileDisc(size( (n)-[]-() ), 0.5) as medDeg, 
min(size( (n)-[]-() ) ) as minDeg,
max(size( (n)-[]-() ) ) as maxDeg""")

pd.DataFrame(
    [list(record.values()) for record in yield_record(cur)] + [[['COMMENTED'], Ncomments]], 
    columns=['Label', 'N', 'Avg. Degree', 'Std. Dev. Degree', 'Median Degree', 'Min. Degree', 'Max. Degree']
)
# Out:
#          Label        N  Avg. Degree  Std. Dev. Degree  Median Degree  \
# 0    [ARTICLE]     9298   185.409228        315.736664           57.0
# 1       [USER]   301682     5.714411         21.186375            1.0
# 2  [COMMENTED]  1723935          NaN               NaN            NaN
#
#    Min. Degree  Max. Degree
# 0          1.0       4996.0
# 1          0.0       1571.0
# 2          NaN          NaN

# %% [markdown]
# ### What articles have the highest degree (i.e., most comments)?

# %%
cur = graph.run("""MATCH (a:ARTICLE)
WITH a, SIZE(()-[:COMMENTED]->(a)) as cmtCnt
ORDER BY cmtCnt DESC LIMIT 5
MATCH p=()-[:COMMENTED]->(a)
RETURN a, count(p)""")

pd.DataFrame([{**res['a'], 'Comments': res['count(p)']} for res in yield_record(cur)]) \
    .sort_values('Comments', ascending=False) \
    .set_index('articleID') \
    .style.format({'webURL': lambda x: f'<a target="_blank" href="{x}"">Link</a>'})
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_72671b42_2685_11e9_b36e_0242ac120003" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Comments</th>
#         <th class="col_heading level0 col1" >byline</th>
#         <th class="col_heading level0 col2" >connComponent</th>
#         <th class="col_heading level0 col3" >headline</th>
#         <th class="col_heading level0 col4" >labelProp</th>
#         <th class="col_heading level0 col5" >newDesk</th>
#         <th class="col_heading level0 col6" >pagerank</th>
#         <th class="col_heading level0 col7" >pubDate</th>
#         <th class="col_heading level0 col8" >webURL</th>
#     </tr>    <tr>
#         <th class="index_name level0" >articleID</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_72671b42_2685_11e9_b36e_0242ac120003level0_row0" class="row_heading level0 row0" >58b0894195d0e0247463875e</th>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row0_col0" class="data row0 col0" >4996</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row0_col1" class="data row0 col1" >By JULIE HIRSCHFELD DAVIS and MICHAEL M. GRYNBAUM</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row0_col2" class="data row0 col2" >155742</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row0_col3" class="data row0 col3" >Trump Intensifies Criticism of F.B.I. and Journalists</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row0_col4" class="data row0 col4" >1749</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row0_col5" class="data row0 col5" >National</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row0_col6" class="data row0 col6" >195.696</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row0_col7" class="data row0 col7" >2017-02-24 19:27:53</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row0_col8" class="data row0 col8" ><a target="_blank" href="https://www.nytimes.com/2017/02/24/us/politics/white-house-sean-spicer-briefing.html"">Link</a></td>
#     </tr>    <tr>
#         <th id="T_72671b42_2685_11e9_b36e_0242ac120003level0_row1" class="row_heading level0 row1" >5912391b7c459f24986de9ab</th>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row1_col0" class="data row1 col0" >4184</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row1_col1" class="data row1 col1" >By MICHAEL D. SHEAR and MATT APUZZO</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row1_col2" class="data row1 col2" >173896</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row1_col3" class="data row1 col3" >Trump Fires Comey Amid Russia Inquiry</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row1_col4" class="data row1 col4" >15988</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row1_col5" class="data row1 col5" >National</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row1_col6" class="data row1 col6" >157.107</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row1_col7" class="data row1 col7" >2017-05-09 21:48:03</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row1_col8" class="data row1 col8" ><a target="_blank" href="https://www.nytimes.com/2017/05/09/us/politics/james-comey-fired-fbi.html"">Link</a></td>
#     </tr>    <tr>
#         <th id="T_72671b42_2685_11e9_b36e_0242ac120003level0_row2" class="row_heading level0 row2" >58ebb1437c459f24986d96ed</th>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row2_col0" class="data row2 col0" >4014</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row2_col1" class="data row2 col1" >By DANIEL VICTOR and MATT STEVENS</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row2_col2" class="data row2 col2" >173896</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row2_col3" class="data row2 col3" >Man Is Dragged From a Full Jet, Stirring a Furor</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row2_col4" class="data row2 col4" >2781</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row2_col5" class="data row2 col5" >Business</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row2_col6" class="data row2 col6" >239.803</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row2_col7" class="data row2 col7" >2017-04-10 16:22:22</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row2_col8" class="data row2 col8" ><a target="_blank" href="https://www.nytimes.com/2017/04/10/business/united-flight-passenger-dragged.html"">Link</a></td>
#     </tr>    <tr>
#         <th id="T_72671b42_2685_11e9_b36e_0242ac120003level0_row3" class="row_heading level0 row3" >591a524d7c459f24986dfc28</th>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row3_col0" class="data row3 col0" >3791</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row3_col1" class="data row3 col1" >By DAVID BROOKS</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row3_col2" class="data row3 col2" >173896</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row3_col3" class="data row3 col3" >When a Child Is Leading The World</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row3_col4" class="data row3 col4" >16169</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row3_col5" class="data row3 col5" >OpEd</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row3_col6" class="data row3 col6" >165.153</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row3_col7" class="data row3 col7" >2017-05-16 01:13:44</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row3_col8" class="data row3 col8" ><a target="_blank" href="https://www.nytimes.com/2017/05/15/opinion/trump-classified-data.html"">Link</a></td>
#     </tr>    <tr>
#         <th id="T_72671b42_2685_11e9_b36e_0242ac120003level0_row4" class="row_heading level0 row4" >5930616f7c459f24986e2e41</th>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row4_col0" class="data row4 col0" >3709</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row4_col1" class="data row4 col1" >By MICHAEL D. SHEAR</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row4_col2" class="data row4 col2" >173896</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row4_col3" class="data row4 col3" >Trump Abandoning Global Climate Accord</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row4_col4" class="data row4 col4" >27060</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row4_col5" class="data row4 col5" >Foreign</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row4_col6" class="data row4 col6" >171.479</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row4_col7" class="data row4 col7" >2017-06-01 18:48:08</td>
#         <td id="T_72671b42_2685_11e9_b36e_0242ac120003row4_col8" class="data row4 col8" ><a target="_blank" href="https://www.nytimes.com/2017/06/01/climate/trump-paris-climate-agreement.html"">Link</a></td>
#     </tr></tbody>
# </table>

# %% [markdown]
# ### What users have the highest degree (i.e., most comments)?

# %%
cur = graph.run("""MATCH (u:USER)
WITH u, SIZE((u)-[:COMMENTED]->()) as cmtCnt
ORDER BY cmtCnt DESC LIMIT 5
MATCH p=(u)-[:COMMENTED]->()
RETURN u, count(p)""")

pd.DataFrame([{**res['u'], 'Comments': res['count(p)']} for res in yield_record(cur)]) \
    .sort_values('Comments', ascending=False) \
    .set_index('userID')
# Out:
#             Comments  connComponent  labelProp  pagerank    userDisplayName  \
# userID
# 61986282.0      1571         155742      62885      0.15  Phyliss Dalmatian
# 17374907.0      1235         155742      44749      0.15         Blackmamba
# 47123844.0      1232         155742      62885      0.15   Richard Luettgen
# 47112177.0      1174         155742       6882      0.15          manfred m
# 37475504.0      1157         155742       6882      0.15           John Doe
#
#                userLocation
# userID
# 61986282.0  Wichita, Kansas
# 17374907.0               Il
# 47123844.0       New Jersey
# 47112177.0          Bolivia
# 37475504.0        Johnstown

# %% [markdown]
# # Run PageRank and Connected Components

# %%
op = """CALL algo.pageRank(null, null, {iterations:20, dampingFactor:0.85, write: true, writeProperty:"pagerank"})
YIELD nodes, iterations, loadMillis, computeMillis, writeMillis, dampingFactor, write, writeProperty"""
pd.DataFrame([graph.run(op).next().data()])
# Out:
#    computeMillis  dampingFactor  iterations  loadMillis   nodes  write  \
# 0            178           0.85          20         782  310980   True
#
#    writeMillis writeProperty
# 0         5836      pagerank

# %%
op = """CALL algo.unionFind(null, null, {write:true, partitionProperty:"connComponent"})
YIELD nodes, setCount, loadMillis, computeMillis, writeMillis;"""
pd.DataFrame([graph.run(op).next().data()])
# Out:
#    computeMillis  loadMillis   nodes  setCount  writeMillis
# 0             93         577  310980      2369         5303

# %% [markdown]
# ## How many subgraphs are there?

# %%
op = """MATCH (n) RETURN distinct(n.connComponent) as partition, count(*) as nNodes ORDER by nNodes DESC"""
cur = graph.run(op)
records = list(yield_record(cur))
print('Subgraphs: {}'.format(len(records)))
pd.DataFrame(records).set_index('partition').head()
# Out:
# Subgraphs: 2369
#            nNodes
# partition
# 155742     208774
# 173896      99666
# 158068         13
# 195223          6
# 258842          6

# %% [markdown]
# ## What are the most influential articles?

# %%
cur = graph.run("""MATCH (n:ARTICLE)
RETURN n
ORDER by n.pagerank
DESC LIMIT 5""")
pd.DataFrame([rec['n'] for rec in yield_record(cur)]) \
    .sort_values('pagerank', ascending=False) \
    .set_index('articleID') \
    .drop('connComponent', axis=1) \
    .style.format({'webURL': lambda x: f'<a target="_blank" href="{x}"">Link</a>'})
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_7b07ed80_2685_11e9_b36e_0242ac120003" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >byline</th>
#         <th class="col_heading level0 col1" >headline</th>
#         <th class="col_heading level0 col2" >labelProp</th>
#         <th class="col_heading level0 col3" >newDesk</th>
#         <th class="col_heading level0 col4" >pagerank</th>
#         <th class="col_heading level0 col5" >pubDate</th>
#         <th class="col_heading level0 col6" >webURL</th>
#     </tr>    <tr>
#         <th class="index_name level0" >articleID</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_7b07ed80_2685_11e9_b36e_0242ac120003level0_row0" class="row_heading level0 row0" >58e4d28e7c459f24986d87c9</th>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row0_col0" class="data row0 col0" >By KATHERINE SCHULTEN</td>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row0_col1" class="data row0 col1" >Our Eighth Annual Found Poem Student Contest</td>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row0_col2" class="data row0 col2" >2095</td>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row0_col3" class="data row0 col3" >Learning</td>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row0_col4" class="data row0 col4" >272.599</td>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row0_col5" class="data row0 col5" >2017-04-05 11:18:34</td>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row0_col6" class="data row0 col6" ><a target="_blank" href="https://www.nytimes.com/2017/04/05/learning/our-eighth-annual-found-poem-student-contest.html"">Link</a></td>
#     </tr>    <tr>
#         <th id="T_7b07ed80_2685_11e9_b36e_0242ac120003level0_row1" class="row_heading level0 row1" >58ebb1437c459f24986d96ed</th>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row1_col0" class="data row1 col0" >By DANIEL VICTOR and MATT STEVENS</td>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row1_col1" class="data row1 col1" >Man Is Dragged From a Full Jet, Stirring a Furor</td>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row1_col2" class="data row1 col2" >2781</td>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row1_col3" class="data row1 col3" >Business</td>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row1_col4" class="data row1 col4" >239.803</td>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row1_col5" class="data row1 col5" >2017-04-10 16:22:22</td>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row1_col6" class="data row1 col6" ><a target="_blank" href="https://www.nytimes.com/2017/04/10/business/united-flight-passenger-dragged.html"">Link</a></td>
#     </tr>    <tr>
#         <th id="T_7b07ed80_2685_11e9_b36e_0242ac120003level0_row2" class="row_heading level0 row2" >58b0894195d0e0247463875e</th>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row2_col0" class="data row2 col0" >By JULIE HIRSCHFELD DAVIS and MICHAEL M. GRYNBAUM</td>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row2_col1" class="data row2 col1" >Trump Intensifies Criticism of F.B.I. and Journalists</td>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row2_col2" class="data row2 col2" >1749</td>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row2_col3" class="data row2 col3" >National</td>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row2_col4" class="data row2 col4" >195.696</td>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row2_col5" class="data row2 col5" >2017-02-24 19:27:53</td>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row2_col6" class="data row2 col6" ><a target="_blank" href="https://www.nytimes.com/2017/02/24/us/politics/white-house-sean-spicer-briefing.html"">Link</a></td>
#     </tr>    <tr>
#         <th id="T_7b07ed80_2685_11e9_b36e_0242ac120003level0_row3" class="row_heading level0 row3" >5930616f7c459f24986e2e41</th>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row3_col0" class="data row3 col0" >By MICHAEL D. SHEAR</td>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row3_col1" class="data row3 col1" >Trump Abandoning Global Climate Accord</td>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row3_col2" class="data row3 col2" >27060</td>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row3_col3" class="data row3 col3" >Foreign</td>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row3_col4" class="data row3 col4" >171.479</td>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row3_col5" class="data row3 col5" >2017-06-01 18:48:08</td>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row3_col6" class="data row3 col6" ><a target="_blank" href="https://www.nytimes.com/2017/06/01/climate/trump-paris-climate-agreement.html"">Link</a></td>
#     </tr>    <tr>
#         <th id="T_7b07ed80_2685_11e9_b36e_0242ac120003level0_row4" class="row_heading level0 row4" >591a524d7c459f24986dfc28</th>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row4_col0" class="data row4 col0" >By DAVID BROOKS</td>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row4_col1" class="data row4 col1" >When a Child Is Leading The World</td>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row4_col2" class="data row4 col2" >16169</td>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row4_col3" class="data row4 col3" >OpEd</td>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row4_col4" class="data row4 col4" >165.153</td>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row4_col5" class="data row4 col5" >2017-05-16 01:13:44</td>
#         <td id="T_7b07ed80_2685_11e9_b36e_0242ac120003row4_col6" class="data row4 col6" ><a target="_blank" href="https://www.nytimes.com/2017/05/15/opinion/trump-classified-data.html"">Link</a></td>
#     </tr></tbody>
# </table>

# %% [markdown]
# ## Simple collaborative filtering

# %%
cur = graph.run("""MATCH (n:ARTICLE) 
WITH n, rand() as r
ORDER BY r
RETURN n
LIMIT 1
""")
article = cur.next().data()['n']
pd.DataFrame([article]).set_index('articleID').style.format({'webURL': lambda x: f'<a target="_blank" href="{x}"">Link</a>'})
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_78ef5406_2686_11e9_b36e_0242ac120003" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >byline</th>
#         <th class="col_heading level0 col1" >connComponent</th>
#         <th class="col_heading level0 col2" >headline</th>
#         <th class="col_heading level0 col3" >labelProp</th>
#         <th class="col_heading level0 col4" >newDesk</th>
#         <th class="col_heading level0 col5" >pagerank</th>
#         <th class="col_heading level0 col6" >pubDate</th>
#         <th class="col_heading level0 col7" >webURL</th>
#     </tr>    <tr>
#         <th class="index_name level0" >articleID</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_78ef5406_2686_11e9_b36e_0242ac120003level0_row0" class="row_heading level0 row0" >58fe58e77c459f24986dbd10</th>
#         <td id="T_78ef5406_2686_11e9_b36e_0242ac120003row0_col0" class="data row0 col0" >By NATE COHN</td>
#         <td id="T_78ef5406_2686_11e9_b36e_0242ac120003row0_col1" class="data row0 col1" >173896</td>
#         <td id="T_78ef5406_2686_11e9_b36e_0242ac120003row0_col2" class="data row0 col2" >Big Turnout for Ossoff Surpassed Recent Democratic Benchmarks</td>
#         <td id="T_78ef5406_2686_11e9_b36e_0242ac120003row0_col3" class="data row0 col3" >2904</td>
#         <td id="T_78ef5406_2686_11e9_b36e_0242ac120003row0_col4" class="data row0 col4" >Upshot</td>
#         <td id="T_78ef5406_2686_11e9_b36e_0242ac120003row0_col5" class="data row0 col5" >0.824373</td>
#         <td id="T_78ef5406_2686_11e9_b36e_0242ac120003row0_col6" class="data row0 col6" >2017-04-24 19:58:22</td>
#         <td id="T_78ef5406_2686_11e9_b36e_0242ac120003row0_col7" class="data row0 col7" ><a target="_blank" href="https://www.nytimes.com/2017/04/24/upshot/big-turnout-for-ossoff-surpassed-recent-democratic-benchmarks.html"">Link</a></td>
#     </tr></tbody>
# </table>

# %%
cur = graph.run("""MATCH (n:ARTICLE {{articleID: '{0}'}})-[]-(:USER)-[]-(m:ARTICLE)
WHERE NOT m.articleID = '{0}'
RETURN m""".format(article['articleID']))
df = pd.DataFrame([rec['m'] for rec in yield_record(cur)])
N = pd.DataFrame(df.groupby('articleID').size().rename('N'))
df1 = df.merge(N, left_on='articleID', right_on='articleID').drop_duplicates().set_index('articleID')
df1.sort_values(['N', 'pagerank'], ascending=False).head(5).style.format({'webURL': lambda x: f'<a target="_blank" href="{x}"">Link</a>'})
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_7deb67ba_2686_11e9_b36e_0242ac120003" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >byline</th>
#         <th class="col_heading level0 col1" >connComponent</th>
#         <th class="col_heading level0 col2" >headline</th>
#         <th class="col_heading level0 col3" >labelProp</th>
#         <th class="col_heading level0 col4" >newDesk</th>
#         <th class="col_heading level0 col5" >pagerank</th>
#         <th class="col_heading level0 col6" >pubDate</th>
#         <th class="col_heading level0 col7" >webURL</th>
#         <th class="col_heading level0 col8" >N</th>
#     </tr>    <tr>
#         <th class="index_name level0" >articleID</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_7deb67ba_2686_11e9_b36e_0242ac120003level0_row0" class="row_heading level0 row0" >591a524d7c459f24986dfc28</th>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row0_col0" class="data row0 col0" >By DAVID BROOKS</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row0_col1" class="data row0 col1" >173896</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row0_col2" class="data row0 col2" >When a Child Is Leading The World</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row0_col3" class="data row0 col3" >16169</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row0_col4" class="data row0 col4" >OpEd</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row0_col5" class="data row0 col5" >165.153</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row0_col6" class="data row0 col6" >2017-05-16 01:13:44</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row0_col7" class="data row0 col7" ><a target="_blank" href="https://www.nytimes.com/2017/05/15/opinion/trump-classified-data.html"">Link</a></td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row0_col8" class="data row0 col8" >11</td>
#     </tr>    <tr>
#         <th id="T_7deb67ba_2686_11e9_b36e_0242ac120003level0_row1" class="row_heading level0 row1" >591bb78c7c459f24986dffba</th>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row1_col0" class="data row1 col0" >By ROSS DOUTHAT</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row1_col1" class="data row1 col1" >173896</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row1_col2" class="data row1 col2" >The 25th Amendment Solution for Removing Trump</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row1_col3" class="data row1 col3" >16210</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row1_col4" class="data row1 col4" >OpEd</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row1_col5" class="data row1 col5" >66.1192</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row1_col6" class="data row1 col6" >2017-05-17 02:37:56</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row1_col7" class="data row1 col7" ><a target="_blank" href="https://www.nytimes.com/2017/05/16/opinion/25th-amendment-trump.html"">Link</a></td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row1_col8" class="data row1 col8" >10</td>
#     </tr>    <tr>
#         <th id="T_7deb67ba_2686_11e9_b36e_0242ac120003level0_row2" class="row_heading level0 row2" >59307a537c459f24986e2ea5</th>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row2_col0" class="data row2 col0" >By THE EDITORIAL BOARD</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row2_col1" class="data row2 col1" >173896</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row2_col2" class="data row2 col2" >A Disgraceful Exit From the Paris Pact</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row2_col3" class="data row2 col3" >27065</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row2_col4" class="data row2 col4" >Editorial</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row2_col5" class="data row2 col5" >42.5564</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row2_col6" class="data row2 col6" >2017-06-01 20:34:17</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row2_col7" class="data row2 col7" ><a target="_blank" href="https://www.nytimes.com/2017/06/01/opinion/trump-paris-climate-change-agreement.html"">Link</a></td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row2_col8" class="data row2 col8" >10</td>
#     </tr>    <tr>
#         <th id="T_7deb67ba_2686_11e9_b36e_0242ac120003level0_row3" class="row_heading level0 row3" >5914fd967c459f24986df1d1</th>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row3_col0" class="data row3 col0" >By TIMOTHY EGAN</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row3_col1" class="data row3 col1" >173896</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row3_col2" class="data row3 col2" >Will Anyone in Congress Step Up to Save the Republic?</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row3_col3" class="data row3 col3" >16078</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row3_col4" class="data row3 col4" >OpEd</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row3_col5" class="data row3 col5" >11.8511</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row3_col6" class="data row3 col6" >2017-05-12 00:10:55</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row3_col7" class="data row3 col7" ><a target="_blank" href="https://www.nytimes.com/2017/05/11/opinion/gop-response-comey-firing.html"">Link</a></td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row3_col8" class="data row3 col8" >10</td>
#     </tr>    <tr>
#         <th id="T_7deb67ba_2686_11e9_b36e_0242ac120003level0_row4" class="row_heading level0 row4" >591cfbf47c459f24986e035d</th>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row4_col0" class="data row4 col0" >By NICHOLAS KRISTOF</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row4_col1" class="data row4 col1" >173896</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row4_col2" class="data row4 col2" >Dangerous Times for Trump and the Nation</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row4_col3" class="data row4 col3" >16251</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row4_col4" class="data row4 col4" >OpEd</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row4_col5" class="data row4 col5" >14.2787</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row4_col6" class="data row4 col6" >2017-05-18 01:42:07</td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row4_col7" class="data row4 col7" ><a target="_blank" href="https://www.nytimes.com/2017/05/17/opinion/trump-russia-mueller-special-counsel.html"">Link</a></td>
#         <td id="T_7deb67ba_2686_11e9_b36e_0242ac120003row4_col8" class="data row4 col8" >9</td>
#     </tr></tbody>
# </table>
